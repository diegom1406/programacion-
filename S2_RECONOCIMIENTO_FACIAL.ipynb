# %% [markdown]
# <a href="https://colab.research.google.com/github/diegom1406/programacion-/blob/main/S2_RECONOCIMIENTO_FACIAL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hola mundo")
# Out:
# Hola mundo

# %%
import sys
print(sys.version)
# Out:
# 3.13.15 (main, Aug  6 2026, 11:06:23) [GCC 11.4.0]

# %%
# !pip install opencv-python
# !pip install matplotlib

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6a5d2af9-bc40-4431-b61e-ce2c88b893da" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6a5d2af9-bc40-4431-b61e-ce2c88b893da">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
print(os.listdir())
# Out:
# ['.config', 'famlia.jpg', 'sample_data']

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-14bad884-f581-4ac8-9e5f-3bc4ae87d928" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-14bad884-f581-4ac8-9e5f-3bc4ae87d928">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-42357f76-0beb-4e18-b9c0-65c1e12549ad" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-42357f76-0beb-4e18-b9c0-65c1e12549ad">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
print(os.listdir())
# Out:
# ['.config', 'famlia.jpg', 'una.jpg', 'dos.jpg', 'sample_data']

# %%
import cv2
import matplotlib.pyplot as plt
# Cargar imagen
img = cv2.imread('una.jpg')
# Convertir a escala de grises
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# Cargar modelo Haar Cascade
face_cascade = cv2.CascadeClassifier(
 cv2.data.haarcascades + 'haarcascade_frontalface_default.xml'
)
# Detectar rostros
faces = face_cascade.detectMultiScale(gray, 1.3, 5)
# Dibujar rectángulos
for (x, y, w, h) in faces:
 cv2.rectangle(img, (x,y), (x+w, y+h), (255,0,0), 2)
# Mostrar imagen
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(446.5), np.float64(446.5), np.float64(-0.5))

# %%
import	cv2
import	matplotlib.pyplot	as	plt
#	Cargar	imagen	(ya	corregido)
img	=	cv2.imread('dos.jpg')
#	Convertir	a	escala	de	grises
gray	=	cv2.cvtColor(img,	cv2.COLOR_BGR2GRAY)
#	Cargar	modelo	Haar	Cascade
face_cascade	=	cv2.CascadeClassifier(
 cv2.data.haarcascades	+	'haarcascade_frontalface_default.xml'
)
#	Detectar	rostros
faces	=	face_cascade.detectMultiScale(gray,	scaleFactor=1.3,
minNeighbors=5)
print("Rostros	detectados:",	len(faces))
#	Dibujar	rectángulos
for	(x,	y,	w,	h)	in	faces:
 cv2.rectangle(img,	(x,y),	(x+w,	y+h),	(255,0,0),	2)
#	Mostrar	imagen
plt.imshow(cv2.cvtColor(img,	cv2.COLOR_BGR2RGB))
plt.axis('off')
# Out:
# Rostros	detectados: 0
# (np.float64(-0.5), np.float64(767.5), np.float64(560.5), np.float64(-0.5))

# %%
import	cv2
import	matplotlib.pyplot	as	plt
img	=	cv2.imread('una.jpg')
gray	=	cv2.cvtColor(img,	cv2.COLOR_BGR2GRAY)
face_cascade	=	cv2.CascadeClassifier(
 cv2.data.haarcascades	+	'haarcascade_frontalface_default.xml'
)
faces	=	face_cascade.detectMultiScale(
 gray,
 scaleFactor=1.1,
 minNeighbors=12,
 minSize=(80,	80)
)
filtered_faces	=	[]
for	(x,	y,	w,	h)	in	faces:
 ratio	=	w	/	h
 if	0.85	<	ratio	<	1.15	and	w	>	100:
  filtered_faces.append((x,	y,	w,	h))
print("Rostros	detectados:",	len(faces))
print("Rostros	finales:",	len(filtered_faces))
for	(x,	y,	w,	h)	in	filtered_faces:
 cv2.rectangle(img,	(x,y),	(x+w,	y+h),	(0,255,0),	2)
plt.imshow(cv2.cvtColor(img,	cv2.COLOR_BGR2RGB))
plt.axis('off')
# Out:
# Rostros	detectados: 0
# Rostros	finales: 0
# (np.float64(-0.5), np.float64(446.5), np.float64(446.5), np.float64(-0.5))
